# %% [markdown]
# # Data Exploration and Model 1

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go

# %%
df =  pd.read_csv('input_data/train_clean_4.csv')
df
# Out:
#                                              comment_text  \
# 0       Explanation\nWhy the edits made under my usern...
# 1       D'aww! He matches this background colour I'm s...
# 2       Hey man, I'm really not trying to edit war. It...
# 3       "\nMore\nI can't make any real suggestions on ...
# 4       You, sir, are my hero. Any chance you remember...
# ...                                                   ...
# 184349  you's a muthaf***in lie &#8220;LifeAsKing: 20_...
# 184350  you've gone and broke the wrong heart baby, an...
# 184351  young buck wanna eat.. dat nigguh like I aint ...
# 184352              youu got wild bitches tellin you lies
# 184353  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                                              cleaned_text  label
# 0       explanation why the edits made under my userna...      0
# 1       dawn he matches this background colour im seem...      0
# 2       hey man im really not trying to edit war its j...      0
# 3       more i cant make any real suggestions on impro...      0
# 4       you sir are my hero any chance you remember wh...      0
# ...                                                   ...    ...
# 184349  yous a muthafin lie lifesaving pearls coreyema...      1
# 184350  youve gone and broke the wrong heart baby and ...      0
# 184351  young buck wan na eat dat niggah like i aint f...      1
# 184352              youu got wild bitches tellin you lies      1
# 184353  ruffled ntac eileen dahlia beautiful color com...      0
#
# [184354 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# comment_text    0
# cleaned_text    7
# label           0
# dtype: int64

# %%
#df.mean()

# %%
#fig = px.bar(df.mean())
#fig.update_layout(
#    title="Percentage of each class",
#    xaxis_title="Class",
#    yaxis_title="Percentage",
#    showlegend=False)

# %%
fig = px.bar(df.label.value_counts() / len(df))
fig.update_layout(title='Percent of each class',
                 xaxis_title='Toxic',
                 yaxis_title='Percentage',
                 showlegend=False)
fig.write_image("plots/class_dist.png")

# %% [markdown]
# Based on this, we should do some sort of resampling or not?

# %%
#df['toxic_any'] =  (df[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']].sum(axis=1) > 0).astype(int)

# %%
df.label.mean()
# Out:
# 0.19986005185675385

# %% [markdown]
# Even grouping them all together only 9.85% of the data is toxic. We should do an upsampling. Like he commented, accuracy is high on the papers due to class imbalance.
#
# ## Let's try some topic modelling

# %%
# Create embeddings
sentence_model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
embeddings = sentence_model.encode(df['comment_text'], show_progress_bar=True)

# Create topic model
topic_model = BERTopic() 
topics, _ = topic_model.fit_transform(df['comment_text'], embeddings)

# Show list of clusters
topic_model.get_topic_info()
# Out:
# Batches:   0%|          | 0/5762 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7_/qk3l52vn0yq_bfr65hpjpy4w0000gn/T/ipykernel_23806/1069779544.py in <module>
#       1 # Create embeddings
#       2 sentence_model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
# ----> 3 embeddings = sentence_model.encode(df['comment_text'], show_progress_bar=True)
#       4
#       5 # Create topic model
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     158
#     159             with torch.no_grad():
# --> 160                 out_features = self.forward(features)
#     161
#     162                 if output_value == 'token_embeddings':
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/sentence_transformers/models/Transformer.py in forward(self, features)
#      49             trans_features['token_type_ids'] = features['token_type_ids']
#      50
# ---> 51         output_states = self.auto_model(**trans_features, return_dict=False)
#      52         output_tokens = output_states[0]
#      53
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     842             past_key_values_length=past_key_values_length,
#     843         )
# --> 844         encoder_outputs = self.encoder(
#     845             embedding_output,
#     846             attention_mask=extended_attention_mask,
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     520                 )
#     521             else:
# --> 522                 layer_outputs = layer_module(
#     523                     hidden_states,
#     524                     attention_mask,
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     447             present_key_value = present_key_value + cross_attn_present_key_value
#     448
# --> 449         layer_output = apply_chunking_to_forward(
#     450             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     451         )
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    2184         return torch.cat(output_chunks, dim=chunk_dim)
#    2185
# -> 2186     return forward_fn(*input_tensors)
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in feed_forward_chunk(self, attention_output)
#     459
#     460     def feed_forward_chunk(self, attention_output):
# --> 461         intermediate_output = self.intermediate(attention_output)
#     462         layer_output = self.output(intermediate_output, attention_output)
#     463         return layer_output
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states)
#     360
#     361     def forward(self, hidden_states):
# --> 362         hidden_states = self.dense(hidden_states)
#     363         hidden_states = self.intermediate_act_fn(hidden_states)
#     364         return hidden_states
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/homebrew/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# Interactive visualization
topic_model.visualize_topics()
# Out:
# <div>                            <div id="38356a6c-a1cc-47bc-8567-231fbad88652" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38356a6c-a1cc-47bc-8567-231fbad88652")) {                    Plotly.newPlot(                        "38356a6c-a1cc-47bc-8567-231fbad88652",                        [{"customdata": [[9.810888290405273, 13.940985679626465, 0, "war | nazi | were | israel | battle", 195], [0.24856987595558167, 13.842434883117676, 1, "utc | 2005 | 2014 | 0056 | investigationsfallandspringolympics", 130], [13.972554206848145, 6.331023693084717, 2, "metal | album | music | bang | bass", 111], [-15.972267150878906, -3.1514339447021484, 3, "redirect | incendiary | talkthe | beck | talkjohn", 110], [9.778985977172852, 13.979397773742676, 4, "king | macedonian | their | league | serer", 105], [16.993492126464844, 6.078464508056641, 5, "sources | reliable | source | information | secondary", 101], [2.664851427078247, -1.4626944065093994, 6, "section | plot | removed | bank | martins", 101], [2.6079819202423096, -1.4644744396209717, 7, "tylas | raymond | james | turtle | collect", 91], [10.422684669494629, 2.711448907852173, 8, "sorry | didnt | apology | am | complaint", 90], [-1.7832714319229126, -11.846421241760254, 9, "vandalize | continue | editing | blocked | pages", 89], [0.08659383654594421, 2.012411117553711, 10, "mongo | wtc | tell | why | us", 86], [0.23228217661380768, 2.514909505844116, 11, "ass | bastard | slap | itbitch | eat", 86], [-3.022068500518799, -12.021920204162598, 12, "thanks | thank | help | appreciated | much", 74], [-2.1046030521392822, -11.53298568725586, 13, "grierson | reading | sucks | article | county", 73], [-6.831618785858154, 1.6386510133743286, 14, "links | external | link | films | web", 72], [10.284280776977539, 2.770051956176758, 15, "enyclopedia | teh | free | wikipedia | life", 71], [5.748685359954834, 11.49243450164795, 16, "stop | editing | continue | blocked | vandalize", 71], [16.975086212158203, 6.095481872558594, 17, "book | japan | japanese | italy | medieval", 70], [12.455755233764648, 5.338974952697754, 18, "personal | attacks | me | attack | comments", 66], [9.94190788269043, 13.894371032714844, 19, "policy | editors | incident | aviation | oxygen", 65], [10.401163101196289, 2.6011440753936768, 20, "shared | stop | ip | irrelevant | address", 62], [5.786066055297852, 11.450439453125, 21, "tests | experimenting | sandbox | test | contributing", 62], [16.78360366821289, 6.289482116699219, 22, "church | jesus | catholic | prophet | brothers", 60], [11.078102111816406, 2.528062105178833, 23, "revers | blocked | unblock | block | request", 56], [4.332079887390137, -3.6793150901794434, 24, "speedy | subject | notable | criteria | deletion", 55], [10.349918365478516, 2.7070059776306152, 25, "wiki | bla | dont | youre | give", 52], [13.471229553222656, 6.022704124450684, 26, "football | season | cup | team | played", 50], [4.695249080657959, -3.3153743743896484, 27, "nomination | talkcelticwonder | creation | submission | discussion", 50], [10.50749683380127, 2.6230316162109375, 28, "warning | warnings | talk | fck | page", 48], [5.777981281280518, 11.461953163146973, 29, "vandalism | experiment | sandbox | considered | nonsense", 46], [10.728703498840332, 14.066999435424805, 30, "discussion | consensus | talk | posted | comment", 45], [-2.8914053440093994, -11.93571662902832, 31, "message | email | sent | mail | got", 45], [2.6279118061065674, -1.4538949728012085, 32, "merge | limits | split | panathinaikos | zoning", 45], [12.393348693847656, 5.424365520477295, 33, "he | his | hes | him | le", 43], [13.930855751037598, 6.3032355308532715, 34, "episode | episodes | series | television | puharich", 43], [-2.081228733062744, -11.61034107208252, 35, "sorry ...

# %% [markdown]
# ## Preprocessing data
#
# Text preprocessing is an approach for cleaning and preparing text data for use in a specific context. The ultimate goal of cleaning and preparing text data is to reduce the text to only the words that you need for your NLP goals.
#
# Steps:
#
# 1) Remove punctuation and non-alphabetical characters
#
# 2) Remove words which appear less than 1% of the vocabulary and more than 99%
#
# 3) Apply lowercase to the text
#
# 4) Tokenize
#
# 5) Remove stop words
#
# 6) Steeming - bluntly removing prefixes and suffixes from a word
#
# 7) Lemmatization – replacing a single-word token with its root

# %%
import unicodedata
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk import word_tokenize

# %%
import unicodedata
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk import word_tokenize


def remove_numbers(text):
    '''Removes integers'''
    text = ''.join([i for i in text if not i.isdigit()])
    return text

def remove_punctuation(text):
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)  
    return text

def text_lowercase(text):
    return text.lower()

def strip_whitespace(text):
    text = " ".join(text.split())
    return text

def remove_stopwords(text, lan='english', add_sw = []):

    if lan == 'english':
        sp_en = set(stopwords.words('english'))
        words_tokens = word_tokenize(text)
        text = [i for i in words_tokens if i not in sp_en]
        text = ' '.join(text)

    else:
        print('''Could not remove stopwords. Please specify a language. 
        Only available in English or Spanish''')
        return

    return text

def apply_stemming(text, lan):

    if lan == 'english':
        stemmer_en = SnowballStemmer('english')
        words_tokens = word_tokenize(text)
        text = [stemmer_en.stem(i) for i in words_tokens]
        text = ' '.join(text)
    else:
        print('Stemmer only available in english or spanish')
        return
    
    return text

def clean_text(text, punctuation=True, numbers=True, lowercase=True, 
          whitespace=True, lan = 'english', stopwords = False, stemming = False, add_sw=[]):

    if stopwords:
        text = remove_stopwords(text, lan = lan, add_sw=add_sw)

    if punctuation:
        text = remove_punctuation(text)

    if numbers:
        text = remove_numbers(text)

    if lowercase:
        text = text_lowercase(text)

    if whitespace:
        text = strip_whitespace(text)

    if stemming:
        text = apply_stemming(text, lan = lan)

    return(text)

# %%
clean_comments = [] 
for text in df['comment_text']:
    clean_comments.append(clean_text(text))
    
df['clean_comments'] = clean_comments

# %%
df
# Out:
#                     id                                       comment_text  \
# 0     73aee1d0f4ac3434  I you mistagged this one as it does not meet t...
# 1     78bffc73bde6f503  How do you create a references section on the ...
# 2     aea668767345dcd1     Semi-protected edit request on 15 October 2015
# 3     6161150e0239aaff  "\nOh, look how sweet he is. And what happened...
# 4     c94ad7853c443b4d  "\n\n Taiwan \n\nShouldn't the ""Taiwan""'s be...
# ...                ...                                                ...
# 9995  4c9a5a2d483edb6f  St Mikes \n\nWe really should put up a St. Mik...
# 9996  597b324d55677463  if they dont score a milliuon goals for vinnie...
# 9997  fe21ab6576f42b25  "\n\n Defacing compliant sigs \n\nThis edit ha...
# 9998  fb457ae943eb757f            image \ncan`t get his image to work. =[
# 9999  e11627ab94dff8b4  for your viewng pleasure \n\nhttp://en.wikiped...
#
#       toxic  severe_toxic  obscene  threat  insult  identity_hate  toxic_any  \
# 0         0             0        0       0       0              0      False
# 1         0             0        0       0       0              0      False
# 2         0             0        0       0       0              0      False
# 3         0             0        0       0       0              0      False
# 4         0             0        0       0       0              0      False
# ...     ...           ...      ...     ...     ...            ...        ...
# 9995      0             0        0       0       0              0      False
# 9996      1             0        1       0       1              0       True
# 9997      0             0        0       0       0              0      False
# 9998      0             0        0       0       0              0      False
# 9999      0             0        0       0       0              0      False
#
#                                          clean_comments
# 0     i you mistagged this one as it does not meet t...
# 1     how do you create a references section on the ...
# 2                semi protected edit request on october
# 3     oh look how sweet he is and what happened with...
# 4     taiwan shouldn t the taiwan s be changed to fo...
# ...                                                 ...
# 9995  st mikes we really should put up a st mikes wi...
# 9996  if they dont score a milliuon goals for vinnie...
# 9997  defacing compliant sigs this edit has been par...
# 9998                  image can t get his image to work
# 9999  for your viewng pleasure http en wikipedia org...
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Model 1
#
# We will make a model that selects the most common label in the data, and see what is the performance. This will be our lowest benchmark

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

def model_1(df_test, label_col, most_common_label=0):
    '''
    Input:
    - df (DataFrame) containing the data
    - comments_col (str) Comments column name
    - label_col (str) label column name
    
    Output:
    - model predictions
    - Accuracy
    - F1
    '''
    y_test = df_test[label_col]
    y_pred = [most_common_label]*len(y_test)
    
    print(classification_report(y_test, y_pred))

# %%
model_1(df, 'label')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89     29445
#            1       0.00      0.00      0.00      7327
#
#     accuracy                           0.80     36772
#    macro avg       0.40      0.50      0.44     36772
# weighted avg       0.64      0.80      0.71     36772

# %%
model_1(df, 'comment_text', 'label')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      7401
#            1       0.00      0.00      0.00      1792
#
#     accuracy                           0.81      9193
#    macro avg       0.40      0.50      0.45      9193
# weighted avg       0.65      0.81      0.72      9193
